# %%
import pandas as pd
import os
import warnings
import pickle
import numpy as np
import random
import matplotlib.pyplot as plt

plt.style.use('classic')

warnings.filterwarnings('ignore')

# %%
random.seed(42)

# %%
if os.getcwd().split('/')[-1] != 'market-congestion':
    os.chdir('..')

print(f'working directory: {os.getcwd()}')
# Out:
# working directory: /Users/crinstaniev/Dev/market-congestion

# %%
train_data = pd.read_pickle('data/train.pkl')
test_data = pd.read_pickle('data/test.pkl')

# %% [markdown]
# # Classification

# %% [markdown]
# ## Naïve Algorithm

# %%
MA_WINDOW = 10

# %%
prev_theta = test_data['congested'].shift(1).rolling(window=MA_WINDOW)
congested_count = prev_theta.sum().dropna()

y_pred = congested_count >= 5
y_true = test_data.loc[y_pred.index]['congested']

# %% [markdown]
# ### Performace Metrics

# %%
from sklearn.base import BaseEstimator
from sklearn.metrics import classification_report

import matplotlib.pyplot as plt

# %%
# this class is only for performance benchmark
class NaiveAlgorithm(BaseEstimator):
    def __init__(self, y_pred):
        self.y_pred = y_pred
        self._estimator_type = 'classifier'
        
    def fit(self, X, y):
        pass

    def predict(self, X):
        return self.y_pred.loc[X].values.astype(int)

# %%
mdl = NaiveAlgorithm(y_pred=y_pred)

# %%
X_test = y_true.index.values

# %% [markdown]
# classification report

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.78      0.95      0.86      2407
#         True       0.21      0.04      0.07       668
#
#     accuracy                           0.76      3075
#    macro avg       0.50      0.50      0.47      3075
# weighted avg       0.66      0.76      0.69      3075

# %% [markdown]
# confusion matrix

# %%
from sklearn.metrics import plot_confusion_matrix

# %%
fig, ax = plt.subplots()
plot_confusion_matrix(mdl, X_test, y_true, ax=ax)
ax.set_title('naïve algorithm: confusion matrix')
fig.show()

# %% [markdown]
# ## Ramdom Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier

train_test_dis = pickle.load(open('data/train_test_dis.pkl', 'rb'))

# %%
X_train = train_test_dis['X_train_dis'].astype(float)
y_train = train_test_dis['y_train_dis']['congested'].astype(int)
X_test = train_test_dis['X_test_dis'].astype(float)
y_test = train_test_dis['y_test_dis']['congested'].astype(int)

# %%
mdl = RandomForestClassifier().fit(X_train, y_train)

# %%
print(classification_report(y_test, mdl.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.99      0.88      2407
#            1       0.55      0.03      0.05       668
#
#     accuracy                           0.78      3075
#    macro avg       0.67      0.51      0.46      3075
# weighted avg       0.73      0.78      0.70      3075

# %%
plot_confusion_matrix(mdl, X_test, y_test)
plt.title('confusion matrix')
plt.show()

# %%
from sklearn.metrics import plot_roc_curve

# %%
plot_roc_curve(mdl, X_test, y_test)
plt.grid()
plt.title('ROC Curve')
plt.show()

# %% [markdown]
# ## Decision tree classifier

# %%
mdl = DecisionTreeClassifier().fit(X_train, y_train)

# %%
print(classification_report(y_test, mdl.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80      2407
#            1       0.27      0.27      0.27       668
#
#     accuracy                           0.69      3075
#    macro avg       0.54      0.53      0.53      3075
# weighted avg       0.68      0.69      0.68      3075

# %%
plot_confusion_matrix(mdl, X_test, y_test)
plt.title('confusion matrix')
plt.show()

# %%
plot_roc_curve(mdl, X_test, y_test)
plt.grid()
plt.title('ROC Curve')
plt.show()

# %% [markdown]
# ## MLP classifier

# %%
mdl = MLPClassifier(hidden_layer_sizes=256).fit(X_train, y_train)

# %%
print(classification_report(y_test, mdl.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.92      0.85      2407
#            1       0.32      0.13      0.19       668
#
#     accuracy                           0.75      3075
#    macro avg       0.56      0.53      0.52      3075
# weighted avg       0.69      0.75      0.71      3075

# %%
plot_confusion_matrix(mdl, X_test, y_test)
plt.title('confusion matrix')
plt.show()

# %%
plot_roc_curve(mdl, X_test, y_test)
plt.grid()
plt.title('ROC Curve')
plt.show()

# %% [markdown]
# ## Auto-ML Classifier

# %%
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
train_df = pd.DataFrame(X_train)
train_df['target'] = y_train.values

test_df = pd.DataFrame(X_test)
test_df['target'] = y_test.values

# %%
train_data = TabularDataset(train_df)
test_data = TabularDataset(test_df)

# %%
# predictor = TabularPredictor(
#     path='AutogluonModels/classifier',
#     label='target'
# ).fit(train_data)

predictor = TabularPredictor.load("AutogluonModels/classifier/")

# %%
predictor.leaderboard()
# Out:
#                  model  score_val  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0  WeightedEnsemble_L2   0.793932       0.099904  179.332634                0.002139           0.367631            2       True         10
# 1      NeuralNetFastAI   0.791403       0.035460  172.721381                0.035460         172.721381            1       True          8
# 2             CatBoost   0.788875       0.006149    3.224838                0.006149           3.224838            1       True          5
# 3     RandomForestEntr   0.787611       0.056156    3.018784                0.056156           3.018784            1       True          4
# 4     RandomForestGini   0.785714       0.055114    2.544246                0.055114           2.544246            1       True          3
# 5       NeuralNetTorch   0.783186       0.027286   66.013871                0.027286          66.013871            1       True          9
# 6       ExtraTreesGini   0.780657       0.056297    0.642430                0.056297           0.642430            1       True          6
# 7       ExtraTreesEntr   0.779393       0.055725    0.696730                0.055725           0.696730            1       True          7
# 8       KNeighborsDist   0.743363       0.418089    0.018924                0.418089           0.018924            1       True          2
# 9       KNeighborsUnif   0.742731       0.373856    0.018423                0.373856           0.018423            1       True          1
#                  model  score_val  pred_time_val    fit_time  \
# 0  WeightedEnsemble_L2   0.793932       0.099904  179.332634
# 1      NeuralNetFastAI   0.791403       0.035460  172.721381
# 2             CatBoost   0.788875       0.006149    3.224838
# 3     RandomForestEntr   0.787611       0.056156    3.018784
# 4     RandomForestGini   0.785714       0.055114    2.544246
# 5       NeuralNetTorch   0.783186       0.027286   66.013871
# 6       ExtraTreesGini   0.780657       0.056297    0.642430
# 7       ExtraTreesEntr   0.779393       0.055725    0.696730
# 8       KNeighborsDist   0.743363       0.418089    0.018924
# 9       KNeighborsUnif   0.742731       0.373856    0.018423
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                0.002139           0.367631            2       True
# 1                0.035460         172.721381            1       True
# 2                0.006149           3.224838            1       True
# 3                0.056156           3.018784            1       True
# 4                0.055114           2.544246            1       True
# 5                0.027286          66.013871            1       True
# 6                0.056297           0.642430            1       True
# 7                0.055725           0.696730            1       True
# 8                0.418089           0.018924            1       True
# 9                0.373856           0.018423            1       True
#
#    fit_order
# 0         10
# 1          8
# 2          5
# 3          4
# 4          3
# 5          9
# 6          6
# 7          7
# 8          2
# 9          1

# %%
y_pred = predictor.predict(test_data)

# %%
print(classification_report(test_data['target'], y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      1.00      0.88      2407
#            1       0.59      0.02      0.05       668
#
#     accuracy                           0.78      3075
#    macro avg       0.69      0.51      0.46      3075
# weighted avg       0.74      0.78      0.70      3075

# %%
# wrapper
class AUTOPredictor(BaseEstimator):
    def __init__(self, classifier):
        self.classifier = classifier
        self._estimator_type = 'classifier'
        
    def fit(self, X, y):
        pass

    def predict(self, X):
        return self.classifier.predict(X)
    
    def predict_proba(self, X):
        return self.classifier.predict_proba(X)

# %%
mdl = AUTOPredictor(classifier=predictor)

# %%
plot_confusion_matrix(mdl, test_data, test_data['target'])
plt.title('Auto-ML: Confusion Matrix')
plt.show()

# %%
import sklearn.metrics as metrics
import scikitplot as skplt

# %%
y_probs = predictor.predict_proba(test_data)
preds = y_probs[:][1]
y_true = test_data['target']

skplt.metrics.plot_roc_curve(y_true, y_probs)

plt.grid()
plt.show()

# %% [markdown]
# # Regression

# %% [markdown]
# ## Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
train_data = pd.read_pickle('data/regression_train_df.pkl')[
    ['size', 'transaction_count', 'theta', 'congested', 'theta_ma_prev', 'theta_ma_future']]
test_data = pd.read_pickle('data/regression_test_df.pkl')[
    ['size', 'transaction_count', 'theta', 'congested', 'theta_ma_prev', 'theta_ma_future']]

# %%
mdl = RandomForestRegressor().fit(
    train_data.loc[:, train_data.columns != 'theta_ma_future'],
    train_data.loc[:, train_data.columns == 'theta_ma_future'],
)

# %%
# calculate R2
from sklearn.metrics import r2_score

# %%
r2 = r2_score(test_data['theta_ma_future'],
              mdl.predict(
                  test_data.loc[:, train_data.columns != 'theta_ma_future'])
              )
print(f'R2 Score: {r2}')
# Out:
# R2 Score: -0.11687528718005202

# %%
fig, ax = plt.subplots()

test_data['theta_ma_future'].hist(ax=ax, label='true', alpha=.75)
pd.Series(mdl.predict(
    test_data.loc[:, train_data.columns != 'theta_ma_future'])).hist(ax=ax, label='pred', alpha=.75)

ax.legend()
fig.show()

# %% [markdown]
# ## Auto-ML

# %%
train_data = TabularDataset(train_data)
test_data = TabularDataset(test_data)

# %%
# predictor = TabularPredictor(
#     label='theta_ma_future',
#     path='AutogluonModels/regression/'
# ).fit(train_data)

predictor = TabularPredictor.load("AutogluonModels/regression/")

# %%
predictor.leaderboard(test_data)
# Out:
#                  model  score_test  score_val  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0       NeuralNetTorch   -0.012158  -0.019927        0.023931       0.013952  33.085686                 0.023931                0.013952          33.085686            1       True          7
# 1             CatBoost   -0.012310  -0.019596        0.003256       0.001807   1.139939                 0.003256                0.001807           1.139939            1       True          4
# 2  WeightedEnsemble_L2   -0.012326  -0.019469        0.231011       0.055514  20.895186                 0.010157                0.000239           0.107268            2       True          8
# 3      NeuralNetFastAI   -0.012327  -0.019494        0.027880       0.013327  17.421824                 0.027880                0.013327          17.421824            1       True          6
# 4        ExtraTreesMSE   -0.013283  -0.020030        0.129102       0.038914   0.651485                 0.129102                0.038914           0.651485            1       True          5
# 5      RandomForestMSE   -0.013376  -0.020075        0.189718       0.040141   2.226155                 0.189718                0.040141           2.226155            1       True          3
# 6       KNeighborsUnif   -0.015561  -0.022168        0.006890       0.007262   0.012152                 0.006890                0.007262           0.012152            1       True          1
# 7       KNeighborsDist   -0.016302  -0.023070        0.009031       0.005272   0.008742                 0.009031                0.005272           0.008742            1       True          2
#                  model  score_test  score_val  pred_time_test  pred_time_val  \
# 0       NeuralNetTorch   -0.012158  -0.019927        0.023931       0.013952
# 1             CatBoost   -0.012310  -0.019596        0.003256       0.001807
# 2  WeightedEnsemble_L2   -0.012326  -0.019469        0.231011       0.055514
# 3      NeuralNetFastAI   -0.012327  -0.019494        0.027880       0.013327
# 4        ExtraTreesMSE   -0.013283  -0.020030        0.129102       0.038914
# 5      RandomForestMSE   -0.013376  -0.020075        0.189718       0.040141
# 6       KNeighborsUnif   -0.015561  -0.022168        0.006890       0.007262
# 7       KNeighborsDist   -0.016302  -0.023070        0.009031       0.005272
#
#     fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0  33.085686                 0.023931                0.013952
# 1   1.139939                 0.003256                0.001807
# 2  20.895186                 0.010157                0.000239
# 3  17.421824                 0.027880                0.013327
# 4   0.651485                 0.129102                0.038914
# 5   2.226155                 0.189718                0.040141
# 6   0.012152                 0.006890                0.007262
# 7   0.008742                 0.009031                0.005272
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0          33.085686            1       True          7
# 1           1.139939            1       True          4
# 2           0.107268            2       True          8
# 3          17.421824            1       True          6
# 4           0.651485            1       True          5
# 5           2.226155            1       True          3
# 6           0.012152            1       True          1
# 7           0.008742            1       True          2

# %%
r2 = r2_score(test_data['theta_ma_future'].values,
              predictor.predict(
                  test_data)
              )
print(f'R2 Score: {r2}')
# Out:
# R2 Score: 0.0601786535931782

# %%
fig, ax = plt.subplots()

test_data['theta_ma_future'].hist(ax=ax, label='true', alpha=.75)
pd.Series(predictor.predict(test_data)).hist(ax=ax, label='pred', alpha=.75)

ax.legend()
fig.show()

# %% [markdown]
# # Regression with Volatility

# %%
train_data = pd.read_pickle('data/train_volatility.pkl')[
    ['size', 'transaction_count', 'theta', 'congested', 'theta_ma_prev', 'theta_ma_future', 'volatility']]
test_data = pd.read_pickle('data/test_volatility.pkl')[
    ['size', 'transaction_count', 'theta', 'congested', 'theta_ma_prev', 'theta_ma_future', 'volatility']]

# %%
train_data = TabularDataset(train_data)
test_data = TabularDataset(test_data)

# %%
# predictor = TabularPredictor(
#     label='theta_ma_future',
#     path='AutogluonModels/regression-volatility/'
# ).fit(train_data)

predictor = TabularPredictor.load("AutogluonModels/regression-volatility/")

# %%
predictor.leaderboard(test_data)
# Out:
#                  model  score_test  score_val  pred_time_test  pred_time_val    fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      NeuralNetFastAI   -0.012858  -0.018600        0.027713       0.013725   17.867649                 0.027713                0.013725          17.867649            1       True          6
# 1       NeuralNetTorch   -0.013346  -0.019730        0.023737       0.014531  109.207122                 0.023737                0.014531         109.207122            1       True          7
# 2        ExtraTreesMSE   -0.013683  -0.016324        0.135954       0.040704    0.680541                 0.135954                0.040704           0.680541            1       True          5
# 3       KNeighborsUnif   -0.015780  -0.022814        0.007113       0.006224    0.008994                 0.007113                0.006224           0.008994            1       True          1
# 4       KNeighborsDist   -0.016309  -0.023657        0.007478       0.007488    0.009057                 0.007478                0.007488           0.009057            1       True          2
# 5      RandomForestMSE   -0.017029  -0.012926        0.131156       0.039746    2.245270                 0.131156                0.039746           2.245270            1       True          3
# 6  WeightedEnsemble_L2   -0.018654  -0.012346        0.140865       0.043425   49.159545                 0.002093                0.000264           0.109432            2       True          8
# 7             CatBoost   -0.022231  -0.012723        0.007616       0.003415   46.804843                 0.007616                0.003415          46.804843            1       True          4
#                  model  score_test  score_val  pred_time_test  pred_time_val  \
# 0      NeuralNetFastAI   -0.012858  -0.018600        0.027713       0.013725
# 1       NeuralNetTorch   -0.013346  -0.019730        0.023737       0.014531
# 2        ExtraTreesMSE   -0.013683  -0.016324        0.135954       0.040704
# 3       KNeighborsUnif   -0.015780  -0.022814        0.007113       0.006224
# 4       KNeighborsDist   -0.016309  -0.023657        0.007478       0.007488
# 5      RandomForestMSE   -0.017029  -0.012926        0.131156       0.039746
# 6  WeightedEnsemble_L2   -0.018654  -0.012346        0.140865       0.043425
# 7             CatBoost   -0.022231  -0.012723        0.007616       0.003415
#
#      fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0   17.867649                 0.027713                0.013725
# 1  109.207122                 0.023737                0.014531
# 2    0.680541                 0.135954                0.040704
# 3    0.008994                 0.007113                0.006224
# 4    0.009057                 0.007478                0.007488
# 5    2.245270                 0.131156                0.039746
# 6   49.159545                 0.002093                0.000264
# 7   46.804843                 0.007616                0.003415
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0          17.867649            1       True          6
# 1         109.207122            1       True          7
# 2           0.680541            1       True          5
# 3           0.008994            1       True          1
# 4           0.009057            1       True          2
# 5           2.245270            1       True          3
# 6           0.109432            2       True          8
# 7          46.804843            1       True          4

# %%
r2 = r2_score(test_data['theta_ma_future'].values,
              predictor.predict(
                  test_data)
              )
print(f'R2 Score: {r2}')
# Out:
# R2 Score: -1.0998245808838147

# %%
fig, ax = plt.subplots()

test_data['theta_ma_future'].hist(ax=ax, label='true', alpha=.75)
pd.Series(predictor.predict(test_data)).hist(ax=ax, label='pred', alpha=.75)

ax.legend()
fig.show()
